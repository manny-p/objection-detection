# %%
import numpy as np
import skimage.io
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
img = skimage.io.imread('../images/cat-01.jpg')

# %%
img
# Out:
# array([[[  1, 117, 202],
#         [  1, 117, 202],
#         [  1, 117, 202],
#         ...,
#         [  1, 113, 197],
#         [  0, 114, 197],
#         [  0, 114, 197]],
#
#        [[  1, 117, 202],
#         [  1, 117, 202],
#         [  1, 117, 202],
#         ...,
#         [  1, 113, 197],
#         [  0, 114, 197],
#         [  0, 114, 197]],
#
#        [[  1, 117, 202],
#         [  1, 117, 202],
#         [  1, 117, 202],
#         ...,
#         [  0, 114, 197],
#         [  0, 115, 198],
#         [  0, 115, 198]],
#
#        ...,
#
#        [[ 46, 148, 222],
#         [ 48, 150, 224],
#         [ 50, 150, 225],
#         ...,
#         [ 42, 144, 219],
#         [ 43, 145, 220],
#         [ 45, 145, 221]],
#
#        [[ 43, 147, 220],
#         [ 46, 150, 223],
#         [ 49, 151, 225],
#         ...,
#         [ 39, 142, 217],
#         [ 40, 143, 218],
#         [ 42, 144, 219]],
#
#        [[ 37, 144, 216],
#         [ 42, 149, 221],
#         [ 47, 149, 223],
# ...

# %%
plt.imshow(img)

# %%
img.shape
# Out:
# (2333, 2333, 3)

# %%
# red matrix
r = img[:,:,0] 

# green matrix
g = img[:,:,1] 

# blue matrix 
b = img[:,:,2]

# %%
r.shape
# Out:
# (2333, 2333)

# %%
g.shape
# Out:
# (2333, 2333)

# %%
b.shape
# Out:
# (2333, 2333)
